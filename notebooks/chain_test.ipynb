# %%
import os, sys

# Go up one level from /notebooks to project root
sys.path.append(os.path.abspath(".."))

from prompts.sql_chain import create_custom_sql_chain

chain = create_custom_sql_chain("gpt-4o", "duckdb_finance.duckdb")

response = chain.invoke({"query": "What are total expenses last quarter?"})

print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os, sys
#       2 sys.path.append(os.getcwd())
# ----> 4 from prompts.sql_chain import create_custom_sql_chain
#       6 chain = create_custom_sql_chain("gpt-4o", "duckdb_finance.duckdb")
#       8 response = chain.invoke({"query": "What are total expenses last quarter?"})
#
# ModuleNotFoundError: No module named 'prompts'
